# %%
import os
from pathlib import Path
os.chdir(path = Path(r"C:\Users\apaks\projects\YT-RAG"))

# %%
import pandas as pd

df = pd.read_csv("rag_evaluation/eval_results/g_eval_results.csv")
df.shape
# Out:
# (50, 7)

# %%
df.head()
# Out:
#      test_name model_name  success  correctness_score  correctness_success  \
# 0  test_case_1    gpt-5.4     True           1.000000                 True
# 1  test_case_0    gpt-5.4    False           0.004743                False
# 2  test_case_4    gpt-5.4     True           0.997702                 True
# 3  test_case_2    gpt-5.4     True           0.981757                 True
# 4  test_case_6    gpt-5.4     True           1.000000                 True
#
#    clarity_score  clarity_success
# 0       0.988080             True
# 1       1.000000             True
# 2       0.993991             True
# 3       0.900000             True
# 4       0.937754             True

# %%
df['correctness_score'].mean()
# Out:
# np.float64(0.9336224886263702)

# %%
df['clarity_score'].mean()
# Out:
# np.float64(0.9319072917554523)

# %%
df['correctness_success'].value_counts()
# Out:
# correctness_success
# True     49
# False     1
# Name: count, dtype: int64

# %%
df['clarity_success'].value_counts()
# Out:
# clarity_success
# True    50
# Name: count, dtype: int64
