# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
ytt = YouTubeTranscriptApi()
fetched_transcript = ytt.fetch(video_id= "n_3XDVOVraI")

# %%
fetched_transcript[1]
# Out:
# FetchedTranscriptSnippet(text='podcast episode on the data Professor', start=1.979, duration=5.161)

# %%
video_id = "n_3XDVOVraI"

# %%
def fetch_video_data(video_id):
    try:
        ytt = YouTubeTranscriptApi()
        fetched_transcript = ytt.fetch(video_id)

        video_data = []
        for snippet in fetched_transcript:
            video_data.append({
                "text": snippet.text,
                "start": snippet.start,
                "duration": snippet.duration
            })
        
        return video_data
    except Exception as e:
        raise

# %%
video_data = fetch_video_data(video_id=video_id)

# %%
processed_transcript = []
for i, item in enumerate(video_data):
    if len(item['text']).split(" ") <10:
        text

# %%
fetch_video_data(video_id=video_id)
# Out:
# [{'text': 'alright so welcome back to another',
#   'start': 0.0,
#   'duration': 4.86},
#  {'text': 'podcast episode on the data Professor',
#   'start': 1.979,
#   'duration': 5.161},
#  {'text': 'YouTube channel uh today we have a',
#   'start': 4.86,
#   'duration': 4.02},
#  {'text': 'special guest on the channel we have',
#   'start': 7.14,
#   'duration': 5.34},
#  {'text': "Jess Haberman and I think it's best if",
#   'start': 8.88,
#   'duration': 5.7},
#  {'text': 'Jess could you introduce yourself please',
#   'start': 12.48,
#   'duration': 4.2},
#  {'text': 'sure be happy to', 'start': 14.58, 'duration': 4.02},
#  {'text': "um I'm a director of learning Solutions",
#   'start': 16.68,
#   'duration': 3.96},
#  {'text': 'at Anaconda', 'start': 18.6, 'duration': 6.36},
#  {'text': 'um and I actually previously was senior',
#   'start': 20.64,
#   'duration': 7.68},
#  {'text': "Acquisitions editor at O'Reilly media",
#   'start': 24.96,
#   'duration': 4.68},
#  {'text': 'um overseeing sort of the data science',
#   'start': 28.32,
#   'duration': 3.779},
#  {'text': 'and data engineering space', 'start': 29.64, 'duration': 5.34},
#  {'text': "um and then Anaconda um we're developing",
#   'start': 32.099,
#   'duration': 6.001},
#  {'text': 'a learning platform to help folks up',
#   'start': 34.98,
#   'duration': 5.64},
#  {'text': 'skill and reskill in data science data',
#   'start': 38.1,
#   'duration': 4.86},
#  {'text': 'engineering machine learning all that',
#   'start': 40.62,
#   'duration': 4.439},
#  {'text': 'great stuff learning python', 'start': 42.96, 'duration': 3.419},
#  {'text': "um so yeah I'm really happy to be on the",
#   'start': 45.059,
#   'duration': 3.48},
#  {'text': 'show today yeah awesome yeah and a',
#   'start': 46.379,
#   'duration': 4.321},
#  {'text': 'pleasure to have you yeah so before we',
#   'start': 48.539,
#   'duration': 4.68},
#  {'text': 'get started with other questions I guess',
#   'start': 50.7,
#   'duration': 4.92},
#  {'text': 'it would be awesome to start with the',
#   'start': 53.219,
#   'duration': 4.261},
#  {'text': 'like a short introductory story about',
#   'start': 55.62,
#   'duration': 4.32},
#  {'text': 'your career journey into the data doing',
#   'start': 57.48,
#   'duration': 5.759},
#  {'text': 'mean yeah um so I have a pretty', 'start': 59.94, 'duration': 5.7},
#  {'text': "non-technical background I've been in",
#   'start': 63.239,
#   'duration': 5.161},
#  {'text': 'book publishing my entire career uh so',
#   'start': 65.64,
#   'duration': 4.62},
#  {'text': 'like 14 years', 'start': 68.4, 'duration': 4.62},
#  {'text': 'um from a few different book publishers',
#   'start': 70.26,
#   'duration': 4.8},
#  {'text': 'um I started sort of outdoor um', 'start': 73.02, 'duration': 4.32},
#  {'text': 'Recreation publishing hiking camping',
#   'start': 75.06,
#   'duration': 4.02},
#  {'text': 'climbing stuff like that', 'start': 77.34, 'duration': 4.38},
#  {'text': 'um moved into a more traditional trade',
#   'start': 79.08,
#   'duration': 3.84},
#  {'text': 'publishing', 'start': 81.72, 'duration': 4.259},
#  {'text': 'um cookbooks and health and fitness',
#   'start': 82.92,
#   'duration': 4.68},
#  {'text': 'um all kinds of stuff', 'start': 85.979, 'duration': 3.78},
#  {'text': 'um and then you know', 'start': 87.6, 'duration': 5.339},
#  {'text': 'um I always sort of like yeah I was for',
#   'start': 89.759,
#   'duration': 4.921},
#  {'text': 'for the publishing side I was pretty',
#   'start': 92.939,
#   'duration': 3.061},
#  {'text': 'technical', 'start': 94.68, 'duration': 2.82},
#  {'text': 'um and sort of was fascinated by',
#   'start': 96.0,
#   'duration': 3.119},
#  {'text': 'technology', 'start': 97.5, 'duration': 3.299},
#  {'text': 'um and then on this opportunity at',
#   'start': 99.119,
#   'duration': 3.481},
#  {'text': "O'Reilly media opened up", 'start': 100.799, 'duration': 4.381},
#  {'text': 'um and at that time it was an editor for',
#   'start': 102.6,
#   'duration': 4.44},
#  {'text': 'um overseeing product management and ux',
#   'start': 105.18,
#   'duration': 3.119},
#  {'text': 'design', 'start': 107.04, 'duration': 3.359},
#  {'text': 'um so kind of you know a little bit more',
#   'start': 108.299,
#   'duration': 3.421},
#  {'text': 'technical', 'start': 110.399, 'duration': 2.76},
#  {'text': 'um and I was doing that for a few months',
#   'start': 111.72,
#   'duration': 3.6},
#  {'text': 'and this opportunity opened up more on',
#   'start': 113.159,
#   'duration': 5.881},
#  {'text': 'the data engineering side and uh and',
#   'start': 115.32,
#   'duration': 5.4},
#  {'text': 'sort of they really needed someone it',
#   'start': 119.04,
#   'duration': 3.0},
#  {'text': 'was a space that was really heating up',
#   'start': 120.72,
#   'duration': 4.02},
#  {'text': 'so um so I moved over and started to',
#   'start': 122.04,
#   'duration': 4.14},
#  {'text': 'learn that space', 'start': 124.74, 'duration': 3.6},
#  {'text': 'um and it was definitely a trial by fire',
#   'start': 126.18,
#   'duration': 4.799},
#  {'text': "if it's really an exciting space to",
#   'start': 128.34,
#   'duration': 5.399},
#  {'text': 'learn but again like very technical',
#   'start': 130.979,
#   'duration': 4.381},
#  {'text': 'um and so I had to get up to speed like',
#   'start': 133.739,
#   'duration': 3.36},
#  {'text': 'pretty quickly so', 'start': 135.36, 'duration': 3.48},
#  {'text': 'um did a lot of that by just like',
#   'start': 137.099,
#   'duration': 3.78},
#  {'text': 'talking to a lot of the experts in the',
#   'start': 138.84,
#   'duration': 2.88},
#  {'text': 'space', 'start': 140.879, 'duration': 3.121},
#  {'text': 'um I found that you know people doing',
#   'start': 141.72,
#   'duration': 5.76},
#  {'text': 'work in data tend to be pretty', 'start': 144.0, 'duration': 6.239},
#  {'text': 'um pretty open and and happy to answer',
#   'start': 147.48,
#   'duration': 4.68},
#  {'text': 'questions and generous with their time',
#   'start': 150.239,
#   'duration': 5.101},
#  {'text': 'in very very informative so I learned a',
#   'start': 152.16,
#   'duration': 5.64},
#  {'text': "lot I remember going to the O'Reilly",
#   'start': 155.34,
#   'duration': 5.34},
#  {'text': 'strata conference in San Francisco and',
#   'start': 157.8,
#   'duration': 4.86},
#  {'text': 'just like begging people to talk to me',
#   'start': 160.68,
#   'duration': 4.139},
#  {'text': 'like I was a third grader and like tell',
#   'start': 162.66,
#   'duration': 3.719},
#  {'text': 'me what they were doing and why it was',
#   'start': 164.819,
#   'duration': 2.581},
#  {'text': 'important', 'start': 166.379, 'duration': 3.0},
#  {'text': 'um and I learned so much uh you know',
#   'start': 167.4,
#   'duration': 4.5},
#  {'text': 'just talking to people and um and I',
#   'start': 169.379,
#   'duration': 4.021},
#  {'text': 'still you know do that all the time I',
#   'start': 171.9,
#   'duration': 2.82},
#  {'text': "think what that's what's really exciting",
#   'start': 173.4,
#   'duration': 2.339},
#  {'text': 'is', 'start': 174.72, 'duration': 3.12},
#  {'text': 'um being able to learn constantly you',
#   'start': 175.739,
#   'duration': 4.561},
#  {'text': "know I think that's been the case um you",
#   'start': 177.84,
#   'duration': 4.979},
#  {'text': 'know in my career in publishing and',
#   'start': 180.3,
#   'duration': 4.74},
#  {'text': 'certainly you know developing learning',
#   'start': 182.819,
#   'duration': 5.221},
#  {'text': 'content in a conda and um you know and',
#   'start': 185.04,
#   'duration': 5.94},
#  {'text': 'it was just so exciting to talk to Peter',
#   'start': 188.04,
#   'duration': 4.979},
#  {'text': 'Wang and and the folks at kind of about',
#   'start': 190.98,
#   'duration': 3.839},
#  {'text': 'just like they wanted to develop more',
#   'start': 193.019,
#   'duration': 4.021},
#  {'text': 'content more education', 'start': 194.819, 'duration': 4.081},
#  {'text': 'um for um people learning Python and',
#   'start': 197.04,
#   'duration': 3.72},
#  {'text': 'learning data science and that was',
#   'start': 198.9,
#   'duration': 4.32},
#  {'text': 'definitely in my wheelhouse and I really',
#   'start': 200.76,
#   'duration': 3.899},
#  {'text': 'like the idea to be able to start from',
#   'start': 203.22,
#   'duration': 3.0},
#  {'text': 'scratch and sort of curate that',
#   'start': 204.659,
#   'duration': 3.36},
#  {'text': 'experience for people', 'start': 206.22, 'duration': 5.099},
#  {'text': 'um so it was an exciting jump and um and',
#   'start': 208.019,
#   'duration': 5.22},
#  {'text': 'here we are it feels kind of incredible',
#   'start': 211.319,
#   'duration': 4.5},
#  {'text': "to to realize I've been Anaconda almost",
#   'start': 213.239,
#   'duration': 4.381},
#  {'text': 'a year I think it was right around pycon',
#   'start': 215.819,
#   'duration': 3.721},
#  {'text': 'when I joined last year', 'start': 217.62, 'duration': 3.479},
#  {'text': "um and we've been able to do quite a lot",
#   'start': 219.54,
#   'duration': 4.14},
#  {'text': "it's obviously a pretty fast-paced uh",
#   'start': 221.099,
#   'duration': 4.021},
#  {'text': 'area so', 'start': 223.68, 'duration': 3.0},
#  {'text': "um so we've been able to really",
#   'start': 225.12,
#   'duration': 3.66},
#  {'text': 'accomplish so much and and getting great',
#   'start': 226.68,
#   'duration': 3.9},
#  {'text': 'feedback from our users who are learning',
#   'start': 228.78,
#   'duration': 4.14},
#  {'text': 'a lot you know about about data in',
#   'start': 230.58,
#   'duration': 6.0},
#  {'text': 'Python right yeah yeah a very amazing',
#   'start': 232.92,
#   'duration': 5.22},
#  {'text': 'journey', 'start': 236.58, 'duration': 4.2},
#  {'text': "um yeah so like like you're yourself I",
#   'start': 238.14,
#   'duration': 4.98},
#  {'text': "I'm also from a non-technical background",
#   'start': 240.78,
#   'duration': 5.58},
#  {'text': 'as well I had my first degree in biology',
#   'start': 243.12,
#   'duration': 5.699},
#  {'text': 'and yeah I stumbled upon data science',
#   'start': 246.36,
#   'duration': 4.56},
#  {'text': 'like during research', 'start': 248.819, 'duration': 5.34},
#  {'text': 'um like during my first year of research',
#   'start': 250.92,
#   'duration': 7.26},
#  {'text': 'um and yeah and ever since I used it for',
#   'start': 254.159,
#   'duration': 7.441},
#  {'text': 'my research thesis and used it ever',
#   'start': 258.18,
#   'duration': 5.04},
#  {'text': 'since and', 'start': 261.6, 'duration': 3.599},
#  {'text': 'I mean the field at the time was like',
#   'start': 263.22,
#   'duration': 4.86},
#  {'text': 'data was called Data Mining and data',
#   'start': 265.199,
#   'duration': 6.961},
#  {'text': 'science took off about like 2012',
#   'start': 268.08,
#   'duration': 6.48},
#  {'text': "um and yeah I've gotten involved in",
#   'start': 272.16,
#   'duration': 5.819},
#  {'text': 'YouTube since 2019 and my only work at',
#   'start': 274.56,
#   'duration': 5.699},
#  {'text': 'the time was like for 15 years working',
#   'start': 277.979,
#   'duration': 6.061},
#  {'text': 'in Academia uh teaching uh doing',
#   'start': 280.259,
#   'duration': 8.341},
#  {'text': 'research as a professor and yeah so in',
#   'start': 284.04,
#   'duration': 6.599},
#  {'text': 'the last one and a half year I left',
#   'start': 288.6,
#   'duration': 6.539},
#  {'text': "Academia and I joined Tech and yes I'm",
#   'start': 290.639,
#   'duration': 6.601},
#  {'text': 'currently working as a developer',
#   'start': 295.139,
#   'duration': 4.981},
#  {'text': "Advocate that's very cool yeah and that",
#   'start': 297.24,
#   'duration': 4.739},
#  {'text': "that's sort of like that the teaching",
#   'start': 300.12,
#   'duration': 4.44},
#  {'text': 'skills you gain you know in Academia I',
#   'start': 301.979,
#   'duration': 5.041},
#  {'text': 'mean are just so relevant and you know',
#   'start': 304.56,
#   'duration': 4.68},
#  {'text': 'an industry and like in for YouTube and',
#   'start': 307.02,
#   'duration': 3.48},
#  {'text': 'things like that I mean YouTube is',
#   'start': 309.24,
#   'duration': 4.019},
#  {'text': 'certainly a huge resource for learning',
#   'start': 310.5,
#   'duration': 4.8},
#  {'text': 'um especially if you can do it well I',
#   'start': 313.259,
#   'duration': 4.44},
#  {'text': 'think as like Tech you know as we see',
#   'start': 315.3,
#   'duration': 4.56},
#  {'text': 'sort of um these big strides in',
#   'start': 317.699,
#   'duration': 4.921},
#  {'text': 'technology and in data this sort of like',
#   'start': 319.86,
#   'duration': 5.399},
#  {'text': 'having a the personality of like a straw',
#   'start': 322.62,
#   'duration': 5.579},
#  {'text': 'a strong trainer a strong instructor who',
#   'start': 325.259,
#   'duration': 5.16},
#  {'text': 'can connect with with Learners is like',
#   'start': 328.199,
#   'duration': 4.081},
#  {'text': "something you can't recreate like I",
#   'start': 330.419,
#   'duration': 4.441},
#  {'text': "don't see like chatty PT being able to",
#   'start': 332.28,
#   'duration': 5.22},
#  {'text': 'replace that anytime soon you know',
#   'start': 334.86,
#   'duration': 4.2},
#  {'text': 'um so yeah I think those are like great',
#   'start': 337.5,
#   'duration': 3.78},
#  {'text': 'skills um in sort of these different',
#   'start': 339.06,
#   'duration': 3.66},
#  {'text': 'areas', 'start': 341.28, 'duration': 3.78},
#  {'text': 'right certainly and yeah like you know',
#   'start': 342.72,
#   'duration': 4.74},
#  {'text': 'like when people ask me like they spent',
#   'start': 345.06,
#   'duration': 3.96},
#  {'text': "like almost half of your life you're",
#   'start': 347.46,
#   'duration': 4.44},
#  {'text': 'like doing research teaching and you',
#   'start': 349.02,
#   'duration': 4.44},
#  {'text': 'know working in Academia and then',
#   'start': 351.9,
#   'duration': 3.06},
#  {'text': 'finally', 'start': 353.46, 'duration': 4.079},
#  {'text': "um joining Tech it's like do you think",
#   'start': 354.96,
#   'duration': 4.62},
#  {'text': "it's like a waste of your time to go",
#   'start': 357.539,
#   'duration': 4.081},
#  {'text': 'through Academia and then finally join',
#   'start': 359.58,
#   'duration': 4.02},
#  {'text': 'Tech but then like I I sort of',
#   'start': 361.62,
#   'duration': 4.799},
#  {'text': 'discovered um during this past year uh',
#   'start': 363.6,
#   'duration': 4.86},
#  {'text': 'that a lot of the skill from Academia',
#   'start': 366.419,
#   'duration': 4.62},
#  {'text': 'like yes you mentioned teaching',
#   'start': 368.46,
#   'duration': 4.739},
#  {'text': 'um content creation you know like going',
#   'start': 371.039,
#   'duration': 5.341},
#  {'text': 'through literature uh doing research',
#   'start': 373.199,
#   'duration': 5.94},
#  {'text': 'um on information actually quite similar',
#   'start': 376.38,
#   'duration': 4.92},
#  {'text': 'and and the skill or like readily',
#   'start': 379.139,
#   'duration': 5.28},
#  {'text': "transferable and yeah I guess it's like",
#   'start': 381.3,
#   'duration': 5.399},
#  {'text': 'the path took me to data science and',
#   'start': 384.419,
#   'duration': 4.56},
#  {'text': 'from Academia that helped me to discover',
#   'start': 386.699,
#   'duration': 5.28},
#  {'text': 'about data science and so yeah here we',
#   'start': 388.979,
#   'duration': 6.361},
#  {'text': 'are today yeah it feels very similarly',
#   'start': 391.979,
#   'duration': 5.641},
#  {'text': 'like I feel like I learned you know a',
#   'start': 395.34,
#   'duration': 4.859},
#  {'text': 'lot about content creation and about you',
#   'start': 397.62,
#   'duration': 4.5},
#  {'text': 'know how to um how to think about',
#   'start': 400.199,
#   'duration': 4.021},
#  {'text': 'content as a business you know and how',
#   'start': 402.12,
#   'duration': 5.46},
#  {'text': 'to um you know find find your Niche and',
#   'start': 404.22,
#   'duration': 4.979},
#  {'text': 'find your audience and make sure that',
#   'start': 407.58,
#   'duration': 3.36},
#  {'text': "you're really honing your message to",
#   'start': 409.199,
#   'duration': 4.861},
#  {'text': 'your audience like that is like really a',
#   'start': 410.94,
#   'duration': 4.74},
#  {'text': 'really important skill', 'start': 414.06, 'duration': 3.9},
#  {'text': "um you know and I I think there's",
#   'start': 415.68,
#   'duration': 4.62},
#  {'text': "there's sort of there's folks in data",
#   'start': 417.96,
#   'duration': 3.9},
#  {'text': 'science who are who are developing',
#   'start': 420.3,
#   'duration': 2.94},
#  {'text': 'content and some who you know that',
#   'start': 421.86,
#   'duration': 3.24},
#  {'text': "doesn't necessarily interest them but I",
#   'start': 423.24,
#   'duration': 3.179},
#  {'text': "think if that's an area and if you're",
#   'start': 425.1,
#   'duration': 3.539},
#  {'text': 'want to help others and teach others',
#   'start': 426.419,
#   'duration': 3.961},
#  {'text': "um yeah it's really helpful to have that",
#   'start': 428.639,
#   'duration': 4.62},
#  {'text': 'sort of basis and certainly I um you',
#   'start': 430.38,
#   'duration': 5.099},
#  {'text': 'know yeah publishing and and Tech are',
#   'start': 433.259,
#   'duration': 4.681},
#  {'text': 'very very different', 'start': 435.479, 'duration': 4.981},
#  {'text': 'um you know Industries um but certainly',
#   'start': 437.94,
#   'duration': 4.92},
#  {'text': 'a lot of like skills that that carried',
#   'start': 440.46,
#   'duration': 6.0},
#  {'text': 'over well for me yeah and actually uh it',
#   'start': 442.86,
#   'duration': 5.22},
#  {'text': 'was always my dream you know like to',
#   'start': 446.46,
#   'duration': 4.32},
#  {'text': 'someday published a book uh with with an',
#   'start': 448.08,
#   'duration': 5.1},
#  {'text': 'animal you know on the on the cover yeah',
#   'start': 450.78,
#   'duration': 5.16},
#  {'text': 'for more Riley and yeah hopefully',
#   'start': 453.18,
#   'duration': 4.98},
#  {'text': 'um sometime soon we I could explore that',
#   'start': 455.94,
#   'duration': 4.14},
#  {'text': 'as well yeah let me know if I can help',
#   'start': 458.16,
#   'duration': 5.939},
#  {'text': "you at all it's great I I love I and I",
#   'start': 460.08,
#   'duration': 5.58},
#  {'text': 'miss that a lot like I love working with',
#   'start': 464.099,
#   'duration': 2.94},
#  {'text': 'folks on books', 'start': 465.66, 'duration': 3.0},
#  {'text': 'um like just listening their ideas and',
#   'start': 467.039,
#   'duration': 4.56},
#  {'text': 'helping them formulate like you know how',
#   'start': 468.66,
#   'duration': 5.34},
#  {'text': 'um you know how to turn that into a',
#   'start': 471.599,
#   'duration': 4.32},
#  {'text': "large project that's good you know and",
#   'start': 474.0,
#   'duration': 4.319},
#  {'text': 'out of like uh you know how to think',
#   'start': 475.919,
#   'duration': 4.801},
#  {'text': "about the way you're gonna work on on a",
#   'start': 478.319,
#   'duration': 4.081},
#  {'text': 'book for the next year or two you know',
#   'start': 480.72,
#   'duration': 4.14},
#  {'text': 'like it takes a long time like and and',
#   'start': 482.4,
#   'duration': 4.019},
#  {'text': "even when you finish you're not finished",
#   'start': 484.86,
#   'duration': 3.36},
#  {'text': 'you know like how do you then promote',
#   'start': 486.419,
#   'duration': 3.78},
#  {'text': 'your work and how do you make sure that',
#   'start': 488.22,
#   'duration': 3.419},
#  {'text': "it's reaching your audience and things",
#   'start': 490.199,
#   'duration': 3.541},
#  {'text': "like that it's like it's so it's really",
#   'start': 491.639,
#   'duration': 5.041},
#  {'text': 'rewarding I think either write a book to',
#   'start': 493.74,
#   'duration': 4.38},
#  {'text': 'be involved in sort of the book writing',
#   'start': 496.68,
#   'duration': 3.84},
#  {'text': 'process and editing process', 'start': 498.12, 'duration': 4.74},
#  {'text': "um and it's great oh and and O'Reilly is",
#   'start': 500.52,
#   'duration': 4.26},
#  {'text': 'you know world class so', 'start': 502.86, 'duration': 4.14},
#  {'text': "um so yeah I I think that's a really",
#   'start': 504.78,
#   'duration': 4.259},
#  {'text': 'great goal for you makes total sense',
#   'start': 507.0,
#   'duration': 4.62},
#  {'text': "it's cool awesome yeah like like when I",
#   'start': 509.039,
#   'duration': 4.44},
#  {'text': 'was in Academia like most of like the',
#   'start': 511.62,
#   'duration': 3.299},
#  {'text': 'work that I publish are like', 'start': 513.479, 'duration': 4.021},
#  {'text': 'predominantly based on my research',
#   'start': 514.919,
#   'duration': 3.781},
#  {'text': 'um sometimes I would do like some',
#   'start': 517.5,
#   'duration': 3.839},
#  {'text': 'tertiary information based on like um',
#   'start': 518.7,
#   'duration': 4.5},
#  {'text': 'compiling information from the primary',
#   'start': 521.339,
#   'duration': 5.581},
#  {'text': 'literature and with summarizing that and',
#   'start': 523.2,
#   'duration': 6.54},
#  {'text': 'um most of the the work or ideas are',
#   'start': 526.92,
#   'duration': 6.359},
#  {'text': 'based on like the the ideas that uh like',
#   'start': 529.74,
#   'duration': 5.76},
#  {'text': 'my research group would create and then',
#   'start': 533.279,
#   'duration': 5.821},
#  {'text': 'like create a thesis around that',
#   'start': 535.5,
#   'duration': 6.06},
#  {'text': 'um but in terms of like publishing in',
#   'start': 539.1,
#   'duration': 5.94},
#  {'text': 'Tech or or generally as a book',
#   'start': 541.56,
#   'duration': 5.279},
#  {'text': "um I guess it's much more than like what",
#   'start': 545.04,
#   'duration': 3.6},
#  {'text': 'the authors want to write about right',
#   'start': 546.839,
#   'duration': 3.721},
#  {'text': "yeah I guess there there's other",
#   'start': 548.64,
#   'duration': 3.68},
#  {'text': "information like what's the market",
#   'start': 550.56,
#   'duration': 4.98},
#  {'text': 'demand for such a topic and yeah we',
#   'start': 552.32,
#   'duration': 4.36},
#  {'text': 'would love to hear your thoughts about',
#   'start': 555.54,
#   'duration': 3.0},
#  {'text': "that yeah I think that that's the big",
#   'start': 556.68,
#   'duration': 4.38},
#  {'text': 'jump from Academia right is like is',
#   'start': 558.54,
#   'duration': 4.08},
#  {'text': 'understanding like you have the market',
#   'start': 561.06,
#   'duration': 4.92},
#  {'text': 'and the business side and you know',
#   'start': 562.62,
#   'duration': 5.94},
#  {'text': 'because you may have a great idea but if',
#   'start': 565.98,
#   'duration': 3.96},
#  {'text': 'like someone else has a great idea',
#   'start': 568.56,
#   'duration': 3.36},
#  {'text': "that's already kind of like the market",
#   'start': 569.94,
#   'duration': 4.2},
#  {'text': 'is sort of um built around and sort of',
#   'start': 571.92,
#   'duration': 4.08},
#  {'text': 'and and sort of pushing up and',
#   'start': 574.14,
#   'duration': 4.259},
#  {'text': "prioritizing then it's far it's very",
#   'start': 576.0,
#   'duration': 3.959},
#  {'text': 'hard to sort of find your Niche there',
#   'start': 578.399,
#   'duration': 3.781},
#  {'text': "it's you know I think there's uh",
#   'start': 579.959,
#   'duration': 4.681},
#  {'text': 'opportunities to find gaps in in',
#   'start': 582.18,
#   'duration': 4.92},
#  {'text': 'knowledge where um that you can fill and',
#   'start': 584.64,
#   'duration': 4.56},
#  {'text': "often I think it's about thinking about",
#   'start': 587.1,
#   'duration': 4.919},
#  {'text': 'the way that um people', 'start': 589.2, 'duration': 4.259},
#  {'text': 'um kind of wear their problem where the',
#   'start': 592.019,
#   'duration': 3.241},
#  {'text': 'biggest challenges are and like how you',
#   'start': 593.459,
#   'duration': 3.481},
#  {'text': "can develop content that's solving those",
#   'start': 595.26,
#   'duration': 3.66},
#  {'text': "problems or is helping you know it's",
#   'start': 596.94,
#   'duration': 4.68},
#  {'text': 'giving people tools to improve their',
#   'start': 598.92,
#   'duration': 4.919},
#  {'text': 'work to improve their career', 'start': 601.62, 'duration': 4.26},
#  {'text': 'um and just like tapping into like what',
#   'start': 603.839,
#   'duration': 4.44},
#  {'text': 'is motivating people and and then being',
#   'start': 605.88,
#   'duration': 4.56},
#  {'text': 'able to offer that that content in a way',
#   'start': 608.279,
#   'duration': 4.62},
#  {'text': 'that you know is organized and it just',
#   'start': 610.44,
#   'duration': 4.62},
#  {'text': 'like helps them sort of build up on',
#   'start': 612.899,
#   'duration': 4.5},
#  {'text': 'their own skills and is more about kind',
#   'start': 615.06,
#   'duration': 4.26},
#  {'text': 'of in a grading with their work than',
#   'start': 617.399,
#   'duration': 4.38},
#  {'text': 'like kind of just like telling you know',
#   'start': 619.32,
#   'duration': 4.56},
#  {'text': "um so it's like how do you help people",
#   'start': 621.779,
#   'duration': 4.921},
#  {'text': 'kind of get get those Hands-On skills',
#   'start': 623.88,
#   'duration': 6.54},
#  {'text': 'um and yeah excuse me and um yeah and I',
#   'start': 626.7,
#   'duration': 5.1},
#  {'text': 'think do researching them right the',
#   'start': 630.42,
#   'duration': 3.539},
#  {'text': 'research part I think you know folks',
#   'start': 631.8,
#   'duration': 4.5},
#  {'text': 'from Academia I understand very well but',
#   'start': 633.959,
#   'duration': 4.141},
#  {'text': 'thinking about a little bit like how do',
#   'start': 636.3,
#   'duration': 3.96},
#  {'text': 'you understand sort of like what is',
#   'start': 638.1,
#   'duration': 4.02},
#  {'text': 'relevant in the market', 'start': 640.26, 'duration': 3.54},
#  {'text': 'um because it has to be recent too right',
#   'start': 642.12,
#   'duration': 4.44},
#  {'text': 'like it has to be like this this you',
#   'start': 643.8,
#   'duration': 5.88},
#  {'text': 'know space is changing so fast that a',
#   'start': 646.56,
#   'duration': 4.44},
#  {'text': 'book that was published five years ago',
#   'start': 649.68,
#   'duration': 3.36},
#  {'text': 'may be completely irrelevant you know or',
#   'start': 651.0,
#   'duration': 3.899},
#  {'text': 'or may not be sort of depending on the',
#   'start': 653.04,
#   'duration': 4.2},
#  {'text': 'focus but thinking about the way that',
#   'start': 654.899,
#   'duration': 4.861},
#  {'text': 'you approach a book in terms of how',
#   'start': 657.24,
#   'duration': 4.92},
#  {'text': 'technical is it how um how do you',
#   'start': 659.76,
#   'duration': 4.74},
#  {'text': 'approach with enough technical', 'start': 662.16, 'duration': 4.26},
#  {'text': 'um detail without', 'start': 664.5, 'duration': 3.48},
#  {'text': 'um you know making the book irrelevant',
#   'start': 666.42,
#   'duration': 3.359},
#  {'text': 'you know surely because those tools are',
#   'start': 667.98,
#   'duration': 3.72},
#  {'text': 'going to change so finding the right',
#   'start': 669.779,
#   'duration': 4.261},
#  {'text': "balance is tricky too so there's like so",
#   'start': 671.7,
#   'duration': 4.74},
#  {'text': 'many aspects that I think like you kind',
#   'start': 674.04,
#   'duration': 4.2},
#  {'text': 'of have to grow and you have to kind to',
#   'start': 676.44,
#   'duration': 4.26},
#  {'text': 'learn as you do it like nobody very few',
#   'start': 678.24,
#   'duration': 4.26},
#  {'text': 'people jump into a book knowing', 'start': 680.7, 'duration': 4.56},
#  {'text': 'everything that they need to communicate',
#   'start': 682.5,
#   'duration': 4.38},
#  {'text': 'to their readers you know you learn it',
#   'start': 685.26,
#   'duration': 4.259},
#  {'text': "as you write it so so it's sort of about",
#   'start': 686.88,
#   'duration': 5.04},
#  {'text': "it's a it's quite a process", 'start': 689.519, 'duration': 3.601},
#  {'text': 'right', 'start': 691.92, 'duration': 2.76},
#  {'text': 'um based on your like prior experience',
#   'start': 693.12,
#   'duration': 4.62},
#  {'text': 'uh working in the book industry uh',
#   'start': 694.68,
#   'duration': 5.339},
#  {'text': "what's like the typical like acceptance",
#   'start': 697.74,
#   'duration': 5.039},
#  {'text': 'rate for you know like for making other',
#   'start': 700.019,
#   'duration': 6.121},
#  {'text': 'suggested idea to acceptance or it',
#   'start': 702.779,
#   'duration': 5.461},
#  {'text': 'totally depends so', 'start': 706.14, 'duration': 5.1},
#  {'text': "um there are I think there's um",
#   'start': 708.24,
#   'duration': 4.56},
#  {'text': 'there are a few different ways a',
#   'start': 711.24,
#   'duration': 3.12},
#  {'text': 'publisher might work you know so they',
#   'start': 712.8,
#   'duration': 3.06},
#  {'text': 'might be sort of', 'start': 714.36, 'duration': 3.599},
#  {'text': 'um in taking a lot of ideas they might',
#   'start': 715.86,
#   'duration': 4.08},
#  {'text': 'have sort of a process through which',
#   'start': 717.959,
#   'duration': 4.021},
#  {'text': 'that they review ideas that are coming',
#   'start': 719.94,
#   'duration': 4.5},
#  {'text': 'to them or they might have relationships',
#   'start': 721.98,
#   'duration': 4.38},
#  {'text': 'with like agents which are is not common',
#   'start': 724.44,
#   'duration': 4.079},
#  {'text': 'and typical bubble J', 'start': 726.36, 'duration': 3.96},
#  {'text': "um and then there's the other way where",
#   'start': 728.519,
#   'duration': 4.621},
#  {'text': 'really the Acquisitions editors',
#   'start': 730.32,
#   'duration': 5.699},
#  {'text': 'um are generating the ideas and um and',
#   'start': 733.14,
#   'duration': 5.759},
#  {'text': 'then finding the right talent to um to',
#   'start': 736.019,
#   'duration': 4.56},
#  {'text': 'develop that content and then like',
#   'start': 738.899,
#   'duration': 3.06},
#  {'text': "although and then there's a lot of",
#   'start': 740.579,
#   'duration': 3.121},
#  {'text': 'mixing of the two', 'start': 741.959, 'duration': 4.021},
#  {'text': "um so I would say at O'Reilly we were",
#   'start': 743.7,
#   'duration': 4.199},
#  {'text': 'more on the latter side more like we',
#   'start': 745.98,
#   'duration': 3.9},
#  {'text': 'know the program we want to build we',
#   'start': 747.899,
#   'duration': 3.901},
#  {'text': 'know the topics that we want we know',
#   'start': 749.88,
#   'duration': 3.6},
#  {'text': 'people in the space now we just kind of',
#   'start': 751.8,
#   'duration': 3.36},
#  {'text': 'have to like organize all those ideas',
#   'start': 753.48,
#   'duration': 3.06},
#  {'text': 'together', 'start': 755.16, 'duration': 5.16},
#  {'text': "um so so yeah so there's there's that",
#   'start': 756.54,
#   'duration': 8.28},
#  {'text': "process and there's the um so so when",
#   'start': 760.32,
#   'duration': 6.48},
#  {'text': "you're on that end of the spectrum",
#   'start': 764.82,
#   'duration': 4.319},
#  {'text': "you're having more success usually",
#   'start': 766.8,
#   'duration': 4.56},
#  {'text': "because you're driving the strategy more",
#   'start': 769.139,
#   'duration': 4.38},
#  {'text': "um rather than you know oh I'm in taking",
#   'start': 771.36,
#   'duration': 4.56},
#  {'text': "hundreds of proposals and I'm maybe",
#   'start': 773.519,
#   'duration': 4.681},
#  {'text': 'accepting a few and', 'start': 775.92, 'duration': 6.719},
#  {'text': "um so I I think at O'Reilly", 'start': 778.2, 'duration': 7.259},
#  {'text': 'um probably like 50 to 60 percent of the',
#   'start': 782.639,
#   'duration': 5.88},
#  {'text': 'proposals that got started or were or',
#   'start': 785.459,
#   'duration': 5.581},
#  {'text': 'were um sent to us', 'start': 788.519, 'duration': 5.161},
#  {'text': 'um you know would would be accepted and',
#   'start': 791.04,
#   'duration': 4.68},
#  {'text': 'we would we would move forward with a',
#   'start': 793.68,
#   'duration': 5.219},
#  {'text': 'contract and then right like 10 of those',
#   'start': 795.72,
#   'duration': 5.82},
#  {'text': "may not actually get published there's a",
#   'start': 798.899,
#   'duration': 4.261},
#  {'text': 'lot of you know a lot of times there for',
#   'start': 801.54,
#   'duration': 4.14},
#  {'text': 'a lot of reasons uh projects kind of get',
#   'start': 803.16,
#   'duration': 4.08},
#  {'text': 'hung up and never quite make it to the',
#   'start': 805.68,
#   'duration': 2.94},
#  {'text': 'Finish Line', 'start': 807.24, 'duration': 3.0},
#  {'text': 'um so yeah I think there are definitely',
#   'start': 808.62,
#   'duration': 4.44},
#  {'text': 'other Publishers in this space who have',
#   'start': 810.24,
#   'duration': 5.7},
#  {'text': 'even fewer projects get published and',
#   'start': 813.06,
#   'duration': 4.92},
#  {'text': "that's maybe part of their model is like",
#   'start': 815.94,
#   'duration': 4.74},
#  {'text': "well we're gonna try more ideas we're",
#   'start': 817.98,
#   'duration': 4.799},
#  {'text': "gonna try more um we're gonna invest in",
#   'start': 820.68,
#   'duration': 5.04},
#  {'text': 'more and and you know and then help weed',
#   'start': 822.779,
#   'duration': 4.62},
#  {'text': "out you know those projects that aren't",
#   'start': 825.72,
#   'duration': 4.44},
#  {'text': 'gonna um get sort of on the market',
#   'start': 827.399,
#   'duration': 5.461},
#  {'text': 'um so it could totally it it may differ',
#   'start': 830.16,
#   'duration': 5.94},
#  {'text': 'very like a lot um between between',
#   'start': 832.86,
#   'duration': 4.74},
#  {'text': 'different Publishers depending on their',
#   'start': 836.1,
#   'duration': 2.96},
#  {'text': 'strategies', 'start': 837.6, 'duration': 4.859},
#  {'text': 'right yeah like um like for for myself',
#   'start': 839.06,
#   'duration': 6.04},
#  {'text': "like I haven't really published in a a",
#   'start': 842.459,
#   'duration': 5.101},
#  {'text': 'more like a technical book like like for',
#   'start': 845.1,
#   'duration': 3.96},
#  {'text': 'coding', 'start': 847.56, 'duration': 4.56},
#  {'text': 'um but based on my own uh publication uh',
#   'start': 849.06,
#   'duration': 5.7},
#  {'text': 'history I mostly publish and like um',
#   'start': 852.12,
#   'duration': 7.08},
#  {'text': 'elsevier as a book chapter mom and like',
#   'start': 854.76,
#   'duration': 5.94},
#  {'text': 'research publication', 'start': 859.2, 'duration': 4.319},
#  {'text': 'um in various journals yeah but yeah I',
#   'start': 860.7,
#   'duration': 5.579},
#  {'text': 'guess this is something that I would be',
#   'start': 863.519,
#   'duration': 4.921},
#  {'text': 'interested in and probably take a deeper',
#   'start': 866.279,
#   'duration': 4.981},
#  {'text': 'dive in yeah and I think even like the',
#   'start': 868.44,
#   'duration': 6.0},
#  {'text': 'pace is a big difference like publishing',
#   'start': 871.26,
#   'duration': 5.579},
#  {'text': 'is up slow process you know compare like',
#   'start': 874.44,
#   'duration': 3.54},
#  {'text': "especially when you're used to being in",
#   'start': 876.839,
#   'duration': 3.18},
#  {'text': 'Tech where everything was so fast like',
#   'start': 877.98,
#   'duration': 4.62},
#  {'text': 'and you get responses and like things',
#   'start': 880.019,
#   'duration': 4.56},
#  {'text': "are always moving and and there's a lot",
#   'start': 882.6,
#   'duration': 4.56},
#  {'text': 'of progress and and not to say',
#   'start': 884.579,
#   'duration': 5.401},
#  {'text': "um publishing isn't Progressive but",
#   'start': 887.16,
#   'duration': 5.22},
#  {'text': 'um in some ways it is but uh I think',
#   'start': 889.98,
#   'duration': 4.08},
#  {'text': 'like it slows the process down for a',
#   'start': 892.38,
#   'duration': 3.78},
#  {'text': 'good reason to really Drive quality high',
#   'start': 894.06,
#   'duration': 3.839},
#  {'text': 'quality content and make sure you know',
#   'start': 896.16,
#   'duration': 3.66},
#  {'text': "you're sort of go going through all the",
#   'start': 897.899,
#   'duration': 4.321},
#  {'text': 'Motions because when you skip ahead or',
#   'start': 899.82,
#   'duration': 4.86},
#  {'text': 'you or you try to publish like the',
#   'start': 902.22,
#   'duration': 4.26},
#  {'text': 'audience will see it so so I think',
#   'start': 904.68,
#   'duration': 4.44},
#  {'text': "that's another like a difference and um",
#   'start': 906.48,
#   'duration': 4.38},
#  {'text': 'you know and that is that is a real',
#   'start': 909.12,
#   'duration': 3.36},
#  {'text': "that's a real challenge", 'start': 910.86, 'duration': 3.36},
#  {'text': "um certainly like an anaconda like we're",
#   'start': 912.48,
#   'duration': 3.599},
#  {'text': 'trying to do things so fast so like how',
#   'start': 914.22,
#   'duration': 4.2},
#  {'text': "do we slow it down enough so like we're",
#   'start': 916.079,
#   'duration': 3.901},
#  {'text': 'making sure that the quality of our',
#   'start': 918.42,
#   'duration': 3.12},
#  {'text': 'content is still really high and that',
#   'start': 919.98,
#   'duration': 3.24},
#  {'text': "we're I'm working with the best people",
#   'start': 921.54,
#   'duration': 4.799},
#  {'text': 'and you know but also you know making',
#   'start': 923.22,
#   'duration': 5.46},
#  {'text': 'sure people are getting uh more content',
#   'start': 926.339,
#   'duration': 5.881},
#  {'text': 'you know in a regular basis so uh pace',
#   'start': 928.68,
#   'duration': 5.64},
#  {'text': 'is definitely a challenge too', 'start': 932.22, 'duration': 3.96},
#  {'text': 'right yeah actually', 'start': 934.32, 'duration': 4.079},
#  {'text': 'um the pace of publication or content',
#   'start': 936.18,
#   'duration': 4.86},
#  {'text': 'creation as you mentioned', 'start': 938.399, 'duration': 5.161},
#  {'text': "um is yeah it's really different because",
#   'start': 941.04,
#   'duration': 4.62},
#  {'text': 'like you I mean especially with video it',
#   'start': 943.56,
#   'duration': 4.139},
#  {'text': 'takes so it takes a lot of time you have',
#   'start': 945.66,
#   'duration': 4.02},
#  {'text': 'to do kind of all this editing and so',
#   'start': 947.699,
#   'duration': 3.901},
#  {'text': 'and you want to develop a lot of content',
#   'start': 949.68,
#   'duration': 3.899},
#  {'text': 'so I would love to hear more about like',
#   'start': 951.6,
#   'duration': 3.66},
#  {'text': 'you know how does the pace feel to you',
#   'start': 953.579,
#   'duration': 2.94},
#  {'text': 'do you feel like a lot of pressure to',
#   'start': 955.26,
#   'duration': 3.42},
#  {'text': 'develop a ton of content what is your',
#   'start': 956.519,
#   'duration': 3.18},
#  {'text': 'like', 'start': 958.68, 'duration': 2.519},
#  {'text': "um I don't like your schedule like for",
#   'start': 959.699,
#   'duration': 4.14},
#  {'text': 'when you develop you know video content',
#   'start': 961.199,
#   'duration': 5.94},
#  {'text': "right yeah sure um like let's start from",
#   'start': 963.839,
#   'duration': 5.221},
#  {'text': 'Academia like you know like the the',
#   'start': 967.139,
#   'duration': 3.781},
#  {'text': 'typical content creation would be like',
#   'start': 969.06,
#   'duration': 5.1},
#  {'text': 'do research and then publish it you know',
#   'start': 970.92,
#   'duration': 5.34},
#  {'text': 'like but before publishing it writing a',
#   'start': 974.16,
#   'duration': 4.2},
#  {'text': 'research article and then', 'start': 976.26, 'duration': 4.379},
#  {'text': 'um working on it like with 10 other',
#   'start': 978.36,
#   'duration': 4.02},
#  {'text': 'colleagues who are a part of the',
#   'start': 980.639,
#   'duration': 4.2},
#  {'text': 'research team and you know like every',
#   'start': 982.38,
#   'duration': 4.38},
#  {'text': 'research article would be like a project',
#   'start': 984.839,
#   'duration': 4.201},
#  {'text': 'on its own and at any given point in',
#   'start': 986.76,
#   'duration': 3.18},
#  {'text': 'time', 'start': 989.04, 'duration': 3.9},
#  {'text': 'I would work on like maybe five or or',
#   'start': 989.94,
#   'duration': 5.639},
#  {'text': 'more articles at the same time and the',
#   'start': 992.94,
#   'duration': 4.8},
#  {'text': 'first author and other', 'start': 995.579, 'duration': 4.021},
#  {'text': 'um uh like middle authors are helping',
#   'start': 997.74,
#   'duration': 4.98},
#  {'text': 'out to collaboratively write the the',
#   'start': 999.6,
#   'duration': 5.52},
#  {'text': 'contents and finally I would vet the',
#   'start': 1002.72,
#   'duration': 5.94},
#  {'text': 'article and prepare it into the format',
#   'start': 1005.12,
#   'duration': 6.3},
#  {'text': 'um for for the various publisher because',
#   'start': 1008.66,
#   'duration': 4.5},
#  {'text': 'like every publisher have their own',
#   'start': 1011.42,
#   'duration': 5.039},
#  {'text': 'unique guidelines and formatting',
#   'start': 1013.16,
#   'duration': 5.58},
#  {'text': 'um yeah and actually like there was a',
#   'start': 1016.459,
#   'duration': 4.5},
#  {'text': 'crazy palette um during one of our',
#   'start': 1018.74,
#   'duration': 4.26},
#  {'text': 'coffee chat', 'start': 1020.959, 'duration': 2.82},
#  {'text': 'um', 'start': 1023.0, 'duration': 2.64},
#  {'text': 'I asked the team would it be awesome if',
#   'start': 1023.779,
#   'duration': 3.361},
#  {'text': 'we could create something that could you',
#   'start': 1025.64,
#   'duration': 3.059},
#  {'text': 'know like automatically write research',
#   'start': 1027.14,
#   'duration': 4.799},
#  {'text': 'articles for us like take a a research',
#   'start': 1028.699,
#   'duration': 5.521},
#  {'text': 'graph a graph that we plotted from our',
#   'start': 1031.939,
#   'duration': 5.221},
#  {'text': 'experiment and then like magically have',
#   'start': 1034.22,
#   'duration': 5.459},
#  {'text': 'it write out like the text you know like',
#   'start': 1037.16,
#   'duration': 4.2},
#  {'text': 'describing the results and all of that',
#   'start': 1039.679,
#   'duration': 4.861},
#  {'text': 'and that was like before tpt4 or chat',
#   'start': 1041.36,
#   'duration': 5.339},
#  {'text': 'GPT was to even release and I think we',
#   'start': 1044.54,
#   'duration': 3.48},
#  {'text': 'had that discussion like two to three',
#   'start': 1046.699,
#   'duration': 3.961},
#  {'text': "years ago and it's amazing that you know",
#   'start': 1048.02,
#   'duration': 4.38},
#  {'text': 'like at the beginning of the year with',
#   'start': 1050.66,
#   'duration': 4.5},
#  {'text': 'the release of chat TBT and uh but you',
#   'start': 1052.4,
#   'duration': 4.56},
#  {'text': 'know TBD has been around for quite some',
#   'start': 1055.16,
#   'duration': 4.5},
#  {'text': "time and it's amazing at the fast pace",
#   'start': 1056.96,
#   'duration': 5.219},
#  {'text': 'of the the field and you know like LL',
#   'start': 1059.66,
#   'duration': 5.759},
#  {'text': 'and large language models are you know',
#   'start': 1062.179,
#   'duration': 6.24},
#  {'text': 'like a big thing now in research as well',
#   'start': 1065.419,
#   'duration': 5.941},
#  {'text': "and yeah it's amazing to see how the",
#   'start': 1068.419,
#   'duration': 5.821},
#  {'text': 'field is evolving and actually I would',
#   'start': 1071.36,
#   'duration': 5.16},
#  {'text': 'love to like link that to our second',
#   'start': 1074.24,
#   'duration': 4.62},
#  {'text': 'question is you know like in your',
#   'start': 1076.52,
#   'duration': 5.58},
#  {'text': 'opinion how has data science evolved',
#   'start': 1078.86,
#   'duration': 5.28},
#  {'text': 'like during the past uh three to five',
#   'start': 1082.1,
#   'duration': 3.18},
#  {'text': 'years', 'start': 1084.14, 'duration': 2.1},
#  {'text': 'yeah', 'start': 1085.28, 'duration': 4.82},
#  {'text': 'yeah I think um you know data science',
#   'start': 1086.24,
#   'duration': 7.02},
#  {'text': 'has been this this great funnel you know',
#   'start': 1090.1,
#   'duration': 6.1},
#  {'text': 'for people to move into Data um that in',
#   'start': 1093.26,
#   'duration': 4.86},
#  {'text': "in if you're even if you're not super",
#   'start': 1096.2,
#   'duration': 3.12},
#  {'text': 'technical', 'start': 1098.12, 'duration': 3.24},
#  {'text': 'um I think it you know gives uh it',
#   'start': 1099.32,
#   'duration': 3.9},
#  {'text': 'offers you a lot of skills that are um',
#   'start': 1101.36,
#   'duration': 4.559},
#  {'text': 'really connected to business goals',
#   'start': 1103.22,
#   'duration': 4.079},
#  {'text': 'um are really about communicating',
#   'start': 1105.919,
#   'duration': 4.981},
#  {'text': 'insights and and I think like the funnel',
#   'start': 1107.299,
#   'duration': 4.801},
#  {'text': 'has', 'start': 1110.9, 'duration': 4.2},
#  {'text': 'um you know I it the often quoted like',
#   'start': 1112.1,
#   'duration': 4.92},
#  {'text': 'data scientists is the hottest you know',
#   'start': 1115.1,
#   'duration': 4.319},
#  {'text': 'sexiest job of the 21st century',
#   'start': 1117.02,
#   'duration': 4.56},
#  {'text': "um I think that's changed to some degree",
#   'start': 1119.419,
#   'duration': 4.88},
#  {'text': "I think there's like this um", 'start': 1121.58, 'duration': 5.94},
#  {'text': 'democratization of data science work',
#   'start': 1124.299,
#   'duration': 5.38},
#  {'text': 'um so that you know if you want to move',
#   'start': 1127.52,
#   'duration': 4.98},
#  {'text': 'into Data you can be one of all kinds',
#   'start': 1129.679,
#   'duration': 4.261},
#  {'text': "there's all these different roles now",
#   'start': 1132.5,
#   'duration': 2.76},
#  {'text': "right there's", 'start': 1133.94, 'duration': 3.9},
#  {'text': 'um data engineering and uh and uh',
#   'start': 1135.26,
#   'duration': 5.7},
#  {'text': 'engineering sorry machine learning',
#   'start': 1137.84,
#   'duration': 4.56},
#  {'text': 'Engineers', 'start': 1140.96, 'duration': 3.839},
#  {'text': 'um and and data analysts and sort of and',
#   'start': 1142.4,
#   'duration': 4.44},
#  {'text': 'then like the sort of um collaboration',
#   'start': 1144.799,
#   'duration': 4.861},
#  {'text': 'of these different roles so that there',
#   'start': 1146.84,
#   'duration': 5.04},
#  {'text': 'are actually fewer people now that call',
#   'start': 1149.66,
#   'duration': 4.08},
#  {'text': 'themselves data scientists but more',
#   'start': 1151.88,
#   'duration': 3.659},
#  {'text': 'people in data', 'start': 1153.74, 'duration': 4.74},
#  {'text': "um so so that seems like there's and I",
#   'start': 1155.539,
#   'duration': 4.621},
#  {'text': "don't think that's gonna change I think",
#   'start': 1158.48,
#   'duration': 3.54},
#  {'text': "that's I think we've you know at",
#   'start': 1160.16,
#   'duration': 3.84},
#  {'text': "O'Reilly we talked about oh data",
#   'start': 1162.02,
#   'duration': 3.84},
#  {'text': 'scientists may go away you know because',
#   'start': 1164.0,
#   'duration': 3.9},
#  {'text': 'like what does it mean to be a data',
#   'start': 1165.86,
#   'duration': 4.319},
#  {'text': 'scientist and is that like the the',
#   'start': 1167.9,
#   'duration': 4.86},
#  {'text': 'clearest um explanation description for',
#   'start': 1170.179,
#   'duration': 4.561},
#  {'text': 'what you do in that kind of role and',
#   'start': 1172.76,
#   'duration': 3.6},
#  {'text': 'working with data and sort of what',
#   'start': 1174.74,
#   'duration': 4.14},
#  {'text': "you're able to do so so I think um we'll",
#   'start': 1176.36,
#   'duration': 4.559},
#  {'text': 'continue to get uh quite a lot of people',
#   'start': 1178.88,
#   'duration': 4.44},
#  {'text': 'moving into Data but', 'start': 1180.919, 'duration': 4.5},
#  {'text': "um like something I noticed O'Reilly",
#   'start': 1183.32,
#   'duration': 4.859},
#  {'text': 'published their um they do an annual',
#   'start': 1185.419,
#   'duration': 5.281},
#  {'text': 'report about their learning platform and',
#   'start': 1188.179,
#   'duration': 5.481},
#  {'text': 'data engineering year over year is up 35',
#   'start': 1190.7,
#   'duration': 6.54},
#  {'text': 'so like that is a real like growth area',
#   'start': 1193.66,
#   'duration': 5.019},
#  {'text': 'right now', 'start': 1197.24, 'duration': 3.42},
#  {'text': 'um you know and it seems that way if not',
#   'start': 1198.679,
#   'duration': 4.441},
#  {'text': 'if you know that data is sort of',
#   'start': 1200.66,
#   'duration': 4.74},
#  {'text': 'um reflective of sort of the industry as',
#   'start': 1203.12,
#   'duration': 3.419},
#  {'text': 'a whole', 'start': 1205.4, 'duration': 3.6},
#  {'text': 'um you know and I think the tools are',
#   'start': 1206.539,
#   'duration': 5.161},
#  {'text': 'allowing more on the harder to more',
#   'start': 1209.0,
#   'duration': 5.88},
#  {'text': 'technical work to be done more easily',
#   'start': 1211.7,
#   'duration': 5.339},
#  {'text': 'um you know I think like like stuff like',
#   'start': 1214.88,
#   'duration': 4.62},
#  {'text': 'snowflake very easy to use and just like',
#   'start': 1217.039,
#   'duration': 5.161},
#  {'text': 'allowing more and more people to sort of',
#   'start': 1219.5,
#   'duration': 4.74},
#  {'text': 'um to dive into their data and and',
#   'start': 1222.2,
#   'duration': 3.66},
#  {'text': 'understand it better and communicate',
#   'start': 1224.24,
#   'duration': 4.98},
#  {'text': 'better about it and um you know so I',
#   'start': 1225.86,
#   'duration': 4.679},
#  {'text': 'think the', 'start': 1229.22, 'duration': 4.74},
#  {'text': 'um opportunities with llms and more',
#   'start': 1230.539,
#   'duration': 5.821},
#  {'text': 'automation are gonna continue to just',
#   'start': 1233.96,
#   'duration': 4.8},
# ...
#  {'text': 'developing', 'start': 1866.899, 'duration': 3.421},
#  {'text': 'um just Pathways to', 'start': 1868.039, 'duration': 4.441},
#  {'text': 'um to you know to learn more about data',
#   'start': 1870.32,
#   'duration': 4.26},
#  {'text': 'science to Learn Python to be able to um',
#   'start': 1872.48,
#   'duration': 4.38},
#  {'text': 'to work with within um you know a python',
#   'start': 1874.58,
#   'duration': 3.9},
#  {'text': 'environment', 'start': 1876.86, 'duration': 3.9},
#  {'text': "um that's really exciting we're um you",
#   'start': 1878.48,
#   'duration': 4.38},
#  {'text': "know we're going to be a pycon we'd love",
#   'start': 1880.76,
#   'duration': 5.1},
#  {'text': "for folks to come chat with us uh it's",
#   'start': 1882.86,
#   'duration': 4.439},
#  {'text': "you know it's a really exciting space",
#   'start': 1885.86,
#   'duration': 3.72},
#  {'text': "there's like there's just so much to do",
#   'start': 1887.299,
#   'duration': 4.141},
#  {'text': "there's so much we can accomplish you",
#   'start': 1889.58,
#   'duration': 3.54},
#  {'text': "know there's um so many tools at our",
#   'start': 1891.44,
#   'duration': 3.119},
#  {'text': 'disposal so', 'start': 1893.12, 'duration': 2.7},
#  {'text': "um so we're pulling all these different",
#   'start': 1894.559,
#   'duration': 4.381},
#  {'text': "levers where we're working kind of um",
#   'start': 1895.82,
#   'duration': 5.94},
#  {'text': 'with educational Outreach to um you know',
#   'start': 1898.94,
#   'duration': 5.459},
#  {'text': 'most universities use Anaconda which is',
#   'start': 1901.76,
#   'duration': 6.24},
#  {'text': 'very exciting but you know learning our',
#   'start': 1904.399,
#   'duration': 5.4},
#  {'text': 'learning platform is brand new you know',
#   'start': 1908.0,
#   'duration': 4.26},
#  {'text': 'we only launched in October so just like',
#   'start': 1909.799,
#   'duration': 4.441},
#  {'text': 'spreading the word you know being on',
#   'start': 1912.26,
#   'duration': 3.84},
#  {'text': 'shows like yours and and talking to',
#   'start': 1914.24,
#   'duration': 3.78},
#  {'text': "people about um about what we're able to",
#   'start': 1916.1,
#   'duration': 5.22},
#  {'text': "do so I'd love to talk with folks about",
#   'start': 1918.02,
#   'duration': 5.519},
#  {'text': 'um you know what they want to learn',
#   'start': 1921.32,
#   'duration': 4.859},
#  {'text': 'um you know what skills um are they',
#   'start': 1923.539,
#   'duration': 4.801},
#  {'text': 'having a hard time', 'start': 1926.179, 'duration': 4.021},
#  {'text': "um you know maybe they're they they need",
#   'start': 1928.34,
#   'duration': 3.12},
#  {'text': "to upskill they don't know where to",
#   'start': 1930.2,
#   'duration': 2.099},
#  {'text': 'start', 'start': 1931.46, 'duration': 2.219},
#  {'text': 'um I think we have this opportunity',
#   'start': 1932.299,
#   'duration': 3.181},
#  {'text': "because we're starting from scratch is",
#   'start': 1933.679,
#   'duration': 3.901},
#  {'text': 'to curate that experience so rather than',
#   'start': 1935.48,
#   'duration': 4.319},
#  {'text': "being a place where there's hundreds of",
#   'start': 1937.58,
#   'duration': 4.079},
#  {'text': "python courses we'll like have a few",
#   'start': 1939.799,
#   'duration': 3.541},
#  {'text': "we'll be like take this one and this one",
#   'start': 1941.659,
#   'duration': 3.12},
#  {'text': 'and this one you know and and then',
#   'start': 1943.34,
#   'duration': 3.24},
#  {'text': "you'll be you know and find ways to",
#   'start': 1944.779,
#   'duration': 3.961},
#  {'text': 'assess folks and develop certifications',
#   'start': 1946.58,
#   'duration': 3.78},
#  {'text': 'and things like that so we have some',
#   'start': 1948.74,
#   'duration': 3.6},
#  {'text': 'some definite plans around around those',
#   'start': 1950.36,
#   'duration': 2.939},
#  {'text': 'areas', 'start': 1952.34, 'duration': 2.88},
#  {'text': 'um you know this year', 'start': 1953.299, 'duration': 4.26},
#  {'text': 'um and yeah and and working with working',
#   'start': 1955.22,
#   'duration': 3.54},
#  {'text': 'with', 'start': 1957.559, 'duration': 2.781},
#  {'text': 'um you know academic institutions',
#   'start': 1958.76,
#   'duration': 4.139},
#  {'text': 'universities and community colleges who',
#   'start': 1960.34,
#   'duration': 4.0},
#  {'text': 'have data science', 'start': 1962.899, 'duration': 5.461},
#  {'text': 'you know uh programs and and just uh you',
#   'start': 1964.34,
#   'duration': 6.36},
#  {'text': 'know helping them get their students um',
#   'start': 1968.36,
#   'duration': 5.22},
#  {'text': "up to speed so so lots lots of there's",
#   'start': 1970.7,
#   'duration': 4.56},
#  {'text': 'like I know every time I talk about like',
#   'start': 1973.58,
#   'duration': 3.18},
#  {'text': "there's so much to do like how do we do",
#   'start': 1975.26,
#   'duration': 2.76},
#  {'text': 'it all but', 'start': 1976.76, 'duration': 3.96},
#  {'text': "um we're growing our teams and um and we",
#   'start': 1978.02,
#   'duration': 4.5},
#  {'text': 'have some like just really incredible',
#   'start': 1980.72,
#   'duration': 4.86},
#  {'text': 'very smart people Anaconda who are so',
#   'start': 1982.52,
#   'duration': 5.7},
#  {'text': 'invested in education and sort of in',
#   'start': 1985.58,
#   'duration': 4.44},
#  {'text': 'giving Doc and helping other people',
#   'start': 1988.22,
#   'duration': 2.819},
#  {'text': 'learn', 'start': 1990.02, 'duration': 2.58},
#  {'text': "um that it's it's just very motivating",
#   'start': 1991.039,
#   'duration': 4.201},
#  {'text': 'right yeah amazing and yeah yeah like',
#   'start': 1992.6,
#   'duration': 4.679},
#  {'text': 'before joining Tech when I was in',
#   'start': 1995.24,
#   'duration': 3.12},
#  {'text': 'Academia', 'start': 1997.279, 'duration': 2.701},
#  {'text': 'um like my research group to use',
#   'start': 1998.36,
#   'duration': 4.319},
#  {'text': "Anaconda I've practically an area of our",
#   'start': 1999.98,
#   'duration': 4.98},
#  {'text': 'devices particularly because we love',
#   'start': 2002.679,
#   'duration': 5.1},
#  {'text': 'like conda as well yeah um like I',
#   'start': 2004.96,
#   'duration': 4.5},
#  {'text': 'personally like to use mini conda and',
#   'start': 2007.779,
#   'duration': 3.841},
#  {'text': 'then like programmatically install',
#   'start': 2009.46,
#   'duration': 5.16},
#  {'text': 'libraries and manage environments and',
#   'start': 2011.62,
#   'duration': 5.76},
#  {'text': 'yeah and in all of the tutorials on my',
#   'start': 2014.62,
#   'duration': 5.279},
#  {'text': 'YouTube channel I would version you know',
#   'start': 2017.38,
#   'duration': 4.74},
#  {'text': 'like the the environment using mini',
#   'start': 2019.899,
#   'duration': 6.321},
#  {'text': 'conda and yeah I is a great way to store',
#   'start': 2022.12,
#   'duration': 7.26},
#  {'text': 'or manage the environment for Python and',
#   'start': 2026.22,
#   'duration': 6.16},
#  {'text': 'yeah and also like like late last year I',
#   'start': 2029.38,
#   'duration': 5.82},
#  {'text': "stumbled upon the like the like there's",
#   'start': 2032.38,
#   'duration': 4.98},
#  {'text': 'the Jupiter notebook platform from',
#   'start': 2035.2,
#   'duration': 5.459},
#  {'text': 'Anaconda as well and yeah could you tell',
#   'start': 2037.36,
#   'duration': 5.34},
#  {'text': 'us about that as well sure yeah so',
#   'start': 2040.659,
#   'duration': 4.921},
#  {'text': 'Anaconda notebooks um they are free',
#   'start': 2042.7,
#   'duration': 5.16},
#  {'text': 'um and uh so you can go in you can open',
#   'start': 2045.58,
#   'duration': 4.319},
#  {'text': 'a cloud notebook in in two seconds',
#   'start': 2047.86,
#   'duration': 3.299},
#  {'text': 'really', 'start': 2049.899, 'duration': 3.121},
#  {'text': 'um and start coding which is so exciting',
#   'start': 2051.159,
#   'duration': 3.96},
#  {'text': 'there we use um The Notebook service',
#   'start': 2053.02,
#   'duration': 4.2},
#  {'text': 'quite a lot for learning um you know',
#   'start': 2055.119,
#   'duration': 4.081},
#  {'text': 'most of our courses they encourage you',
#   'start': 2057.22,
#   'duration': 3.659},
#  {'text': 'to create a new notebook or maybe give',
#   'start': 2059.2,
#   'duration': 3.659},
#  {'text': "you um a sort of a notebook that's",
#   'start': 2060.879,
#   'duration': 4.681},
#  {'text': "that's mostly filled out to start",
#   'start': 2062.859,
#   'duration': 4.621},
#  {'text': 'um to allow you to sort of get um you',
#   'start': 2065.56,
#   'duration': 4.02},
#  {'text': 'know get learning really quickly',
#   'start': 2067.48,
#   'duration': 4.679},
#  {'text': 'um and get your pride and get practice',
#   'start': 2069.58,
#   'duration': 4.74},
#  {'text': "um so there yeah so there's um some",
#   'start': 2072.159,
#   'duration': 4.381},
#  {'text': 'capacity limits to the free service',
#   'start': 2074.32,
#   'duration': 4.799},
#  {'text': 'um but then so if you want to upgrade to',
#   'start': 2076.54,
#   'duration': 4.26},
#  {'text': "a higher capacity notebook um that's",
#   'start': 2079.119,
#   'duration': 4.02},
#  {'text': 'part of our our starter tier so starter',
#   'start': 2080.8,
#   'duration': 4.319},
#  {'text': 'tier also includes all of our learning',
#   'start': 2083.139,
#   'duration': 3.301},
#  {'text': 'content', 'start': 2085.119, 'duration': 3.601},
#  {'text': 'um and and this Cloud um the cloud',
#   'start': 2086.44,
#   'duration': 3.719},
#  {'text': "notebooks that's sort of the higher",
#   'start': 2088.72,
#   'duration': 2.399},
#  {'text': 'capacity', 'start': 2090.159, 'duration': 2.281},
#  {'text': "um and that's like nine dollars a month",
#   'start': 2091.119,
#   'duration': 3.06},
#  {'text': 'so we want again like we want it to be',
#   'start': 2092.44,
#   'duration': 3.84},
#  {'text': 'really accessible to folks', 'start': 2094.179, 'duration': 4.501},
#  {'text': 'um and just like help Empower them you',
#   'start': 2096.28,
#   'duration': 4.319},
#  {'text': 'know and their projects', 'start': 2098.68, 'duration': 4.14},
#  {'text': "um so yeah notebooks are great there's a",
#   'start': 2100.599,
#   'duration': 4.26},
#  {'text': "lot of um there's a lot of like cool",
#   'start': 2102.82,
#   'duration': 4.38},
#  {'text': "ways you know it's one tool and and you",
#   'start': 2104.859,
#   'duration': 3.541},
#  {'text': 'know I think we', 'start': 2107.2, 'duration': 3.12},
#  {'text': 'um we use it a lot', 'start': 2108.4, 'duration': 3.9},
#  {'text': "um and and there's I think other other",
#   'start': 2110.32,
#   'duration': 3.84},
#  {'text': 'tools and other opportunities down the',
#   'start': 2112.3,
#   'duration': 4.319},
#  {'text': 'road script is another one so so I think',
#   'start': 2114.16,
#   'duration': 4.98},
#  {'text': 'like giving you know giving folks',
#   'start': 2116.619,
#   'duration': 4.561},
#  {'text': 'um ways to to play around with their',
#   'start': 2119.14,
#   'duration': 4.439},
#  {'text': 'code in in a variety of ways', 'start': 2121.18, 'duration': 4.439},
#  {'text': "um I think it's really important awesome",
#   'start': 2123.579,
#   'duration': 6.061},
#  {'text': 'yeah um and like for the free tier uh is',
#   'start': 2125.619,
#   'duration': 6.0},
#  {'text': "you mentioned there's like a like a",
#   'start': 2129.64,
#   'duration': 3.479},
#  {'text': 'limit', 'start': 2131.619, 'duration': 3.48},
#  {'text': 'um but in terms of like the number of',
#   'start': 2133.119,
#   'duration': 4.141},
#  {'text': 'books that a user could you know like',
#   'start': 2135.099,
#   'duration': 4.621},
#  {'text': 'create is there any limit on that or is',
#   'start': 2137.26,
#   'duration': 6.42},
#  {'text': 'it like yep yeah it has to do with um',
#   'start': 2139.72,
#   'duration': 6.48},
#  {'text': "CPU seconds so that's why I guess a",
#   'start': 2143.68,
#   'duration': 3.48},
#  {'text': "little bit works I've been called in",
#   'start': 2146.2,
#   'duration': 2.46},
#  {'text': 'over a little over my head but if',
#   'start': 2147.16,
#   'duration': 3.179},
#  {'text': "there's a you know I think if you're",
#   'start': 2148.66,
#   'duration': 2.52},
#  {'text': 'doing', 'start': 2150.339, 'duration': 3.78},
#  {'text': 'um if so for example you can use any of',
#   'start': 2151.18,
#   'duration': 5.04},
#  {'text': 'uh you can use um sorry free notebooks',
#   'start': 2154.119,
#   'duration': 4.5},
#  {'text': 'for any of um our our kind of standard',
#   'start': 2156.22,
#   'duration': 4.44},
#  {'text': "learning um courses it's what you're",
#   'start': 2158.619,
#   'duration': 4.441},
#  {'text': 'starting to do more um more work in',
#   'start': 2160.66,
#   'duration': 3.959},
#  {'text': 'machine learning where you hit the',
#   'start': 2163.06,
#   'duration': 3.6},
#  {'text': 'capacity limit just because of like the',
#   'start': 2164.619,
#   'duration': 4.98},
#  {'text': 'amount and the insert of the um the CPU',
#   'start': 2166.66,
#   'duration': 5.22},
#  {'text': "runtime that it's going to require",
#   'start': 2169.599,
#   'duration': 3.421},
#  {'text': "um that's when you start running into",
#   'start': 2171.88,
#   'duration': 3.12},
#  {'text': 'that but um but you can create and you',
#   'start': 2173.02,
#   'duration': 3.72},
#  {'text': 'know you know as many notebooks as you',
#   'start': 2175.0,
#   'duration': 5.04},
#  {'text': 'want download them bring them elsewhere',
#   'start': 2176.74,
#   'duration': 4.92},
#  {'text': "um we're working on sharing capabilities",
#   'start': 2180.04,
#   'duration': 3.36},
#  {'text': 'in the near future', 'start': 2181.66, 'duration': 4.5},
#  {'text': 'um all kinds of cool things within',
#   'start': 2183.4,
#   'duration': 6.3},
#  {'text': 'notebooks um data visualizations and and',
#   'start': 2186.16,
#   'duration': 7.26},
#  {'text': "data sets so um so yeah we're excited to",
#   'start': 2189.7,
#   'duration': 5.159},
#  {'text': 'be able to roll out some more features',
#   'start': 2193.42,
#   'duration': 4.86},
#  {'text': 'around our notebook service in the very',
#   'start': 2194.859,
#   'duration': 5.881},
#  {'text': 'right the second pre-installed with like',
#   'start': 2198.28,
#   'duration': 4.86},
#  {'text': 'all of the essential libraries for doing',
#   'start': 2200.74,
#   'duration': 4.619},
#  {'text': 'data science it does it comes with the',
#   'start': 2203.14,
#   'duration': 4.86},
#  {'text': 'same as Anaconda distribution does so um',
#   'start': 2205.359,
#   'duration': 5.101},
#  {'text': 'so yeah so it means you you can get real',
#   'start': 2208.0,
#   'duration': 3.96},
#  {'text': 'started right away with panda', 'start': 2210.46, 'duration': 3.54},
#  {'text': 'scikit-learn you know kind of all all',
#   'start': 2211.96,
#   'duration': 3.84},
#  {'text': 'this sort of standard libraries that you',
#   'start': 2214.0,
#   'duration': 4.32},
#  {'text': 'probably use all the time right yeah',
#   'start': 2215.8,
#   'duration': 5.16},
#  {'text': 'yeah um yeah hovering back to the',
#   'start': 2218.32,
#   'duration': 4.32},
#  {'text': 'statement you mentioned about like',
#   'start': 2220.96,
#   'duration': 5.76},
#  {'text': 'building a platform like for', 'start': 2222.64, 'duration': 7.439},
#  {'text': 'um allowing users to use python in like',
#   'start': 2226.72,
#   'duration': 5.1},
#  {'text': 'different capacities you mentioned about',
#   'start': 2230.079,
#   'duration': 4.201},
#  {'text': 'like having Anaconda for desktops or',
#   'start': 2231.82,
#   'duration': 4.86},
#  {'text': 'laptops and then having Pi script for',
#   'start': 2234.28,
#   'duration': 5.4},
#  {'text': 'for the web online platform', 'start': 2236.68, 'duration': 5.34},
#  {'text': 'um and how about like mobile platform is',
#   'start': 2239.68,
#   'duration': 5.28},
#  {'text': 'there any solution from Anaconda there',
#   'start': 2242.02,
#   'duration': 6.54},
#  {'text': "um you know uh not that I'm necessarily",
#   'start': 2244.96,
#   'duration': 5.82},
#  {'text': "they're very much they're very good very",
#   'start': 2248.56,
#   'duration': 4.26},
#  {'text': 'well could be but not that um has',
#   'start': 2250.78,
#   'duration': 4.38},
#  {'text': 'necessarily crossed my desk yet',
#   'start': 2252.82,
#   'duration': 4.92},
#  {'text': 'um I know I think decoding is still a',
#   'start': 2255.16,
#   'duration': 5.64},
#  {'text': 'very like machine like poker you know I',
#   'start': 2257.74,
#   'duration': 5.339},
#  ...]
